# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='str')

# %%
df.drop(columns= ['survived', 'pclass', 'sibsp', 'parch', 
       'embarked',  'who', 'adult_male', 'deck'], 
       inplace= True)

# %%
sns.histplot(df, 
             x = 'age', 
             binwidth= 10)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.boxplot(df, x = 'age')
# Out:
# <Axes: xlabel='age'>

# %%
sns.histplot(df, 
             x = 'fare', 
             binwidth= 50)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.boxplot(df, x = 'fare')
# Out:
# <Axes: xlabel='fare'>

# %%
df.describe()
# Out:
#               age        fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
q1 = 7.910400
q2 = 14.454200
q3 = 31.000000
# inter quartile range
iqr = q3 - q1

ul = q3 + 1.5 * iqr
ll = q1 - 1.5 * iqr

print(ul, ll)
# Out:
# 65.6344 -26.724

# %%
sns.regplot(df, x = 'age', y = 'fare')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
df2 = pd.read_clipboard()

# %%
sns.regplot(df2, x = 'Hours_Studied', y = 'Marks_Obtained')
# Out:
# <Axes: xlabel='Hours_Studied', ylabel='Marks_Obtained'>

# %%
df['age'].corr(df['fare'])
# Out:
# np.float64(0.09606669176903894)

# %%
df2['Hours_Studied'].corr(df2['Marks_Obtained'])
# Out:
# np.float64(0.9944338387456394)

# %%
# swarm plot

sns.swarmplot(df, y = 'fare', hue= 'embark_town')
# Out:
# <Axes: ylabel='fare'>
# c:\Users\Acer\AppData\Local\Programs\Python\Python314\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 57.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.jointplot(df, x= 'age', y = 'fare')

# %%
sns.stripplot(df, y = 'fare', x = 'embark_town')
# Out:
# <Axes: xlabel='embark_town', ylabel='fare'>

# %%
# count
# histogram
# box
# scatter
# regplot
# swarmplot
# strip
# joint
# heatmap
# pair
# kde

# %%
sns.pairplot(df, x_vars = ['age', 'fare'], y_vars= ['age', 'fare'])
plt.savefig('pair.png' )

# %%
# sns.violinplot(df, x = 'fare')
