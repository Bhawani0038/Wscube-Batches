# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# ----------------------------
# 1. Create DataFrame
# ----------------------------
data = {
    "Name": ["A", "B", "C", "D", "E"],
    "Age": [22, 21, 22, 35, 36],
    "Salary": [20000.0, 23000.0, 22500.0, 22000.0, 21000.0],
    "Fraud": ["Yes", "No", "Yes", "Yes", "No"]
}

df = pd.DataFrame(data)

# ----------------------------
# 2. Select numeric columns
# ----------------------------
numeric_cols = ["Age", "Salary"]

# ----------------------------
# 3. Apply Standard Scaling
# ----------------------------
scaler = StandardScaler()

df_scaled = df.copy()
df_scaled[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# ----------------------------
# 4. Output
# ----------------------------
print("Original Data:\n")
print(df)

print("\nScaled Data:\n")
print(df_scaled)
# Out:
# Original Data:
#
#   Name  Age   Salary Fraud
# 0    A   22  20000.0   Yes
# 1    B   21  23000.0    No
# 2    C   22  22500.0   Yes
# 3    D   35  22000.0   Yes
# 4    E   36  21000.0    No
#
# Scaled Data:
#
#   Name       Age    Salary Fraud
# 0    A -0.765368 -1.578410   Yes
# 1    B -0.912554  1.207020    No
# 2    C -0.765368  0.742781   Yes
# 3    D  1.148052  0.278543   Yes
# 4    E  1.295239 -0.649934    No
